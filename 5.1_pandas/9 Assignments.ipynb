# %% [markdown]
# ## Assignments
# This section has some more open assignments to rehearse the material on Pandas from the previous sections.

# %%
import pandas as pd
import matplotlib.pyplot as plt
trees_df = pd.read_csv('Bomen_in_beheer_door_gemeente_Delft.csv')

# %% [markdown]
# ### What's the (rounded) mean planting year (`'AANLEGJAAR'`) of trees in the neighborhood `'TU-Campus'`?

# %%
# %%slider
# 1950 2000
# Out:
# IntSlider(value=1950, max=2000, min=1950)

# %%
# %%check
# hashresult == 1780997731
# Out:
# <table><tr style="background: green; color: white"><td style="text-align:left">Correct!</td></tr></table>

# %% [markdown]
# #### Make a figure of the locations of the trees whos property `OMGEVINGSRISICOKLASSEN` has the value `Verhoogd`.
# Assign the result of the scatter plot to the variable `scatter_plot`.

# %%
# %%assignment
# mask = trees_df['OMGEVINGSRISICOKLASSEN'] == 'Verhoogd'
#
# scatter_plot = trees_df[mask].plot.scatter(x='X',y='Y',s=10)
# plt.show()

# %%
# %%check
# points = scatter_plot.axes.collections[0].get_offsets().data
# points.sort()
# hash(str(points)) == 2940761141727026644
# Out:
# <table><tr style="background: green; color: white"><td style="text-align:left">Correct!</td></tr></table>
