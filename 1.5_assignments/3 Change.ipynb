# %% [markdown]
# # Compute change

# %% [markdown]
# Suppose that a person has to pay E16.10 and pays with a E20 bill. Write a program that gives the change in the minimum number of coins. In this case, 1 E2 coin, 1 E1 coin, 1 E0.50 coin and 2 E0.20 coins.
#
# Note: to avoid rounding problems, we will compute in cents, therefore someone has to pay 1610 cents and pays with a 2000 cents bill.
#
# Hint: the modulo (%) and integer division (//) operators will come in handy.

# %% [markdown]
# #### First write an expression that computes the difference between amount and paid, this is the total sum that should be returned.

# %%
amount = 1610
paid = 2000

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# paid, amount = 2000, 1610
# result == 390
# paid, amount = 500, 495
# result == 5

# %% [markdown]
# ### compute the number of E2 coins (200 cents) that will fit into the amount of change

# %%
amount = 1610
paid = 2000

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# paid, amount = 2000, 1610
# result == 1
# paid, amount = 2000, 1600
# result == 2

# %% [markdown]
# ### After you have given the right number of E2 coins how much change do you still have to return?

# %%
amount = 1610
paid = 2000

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# paid, amount = 2000, 1610
# result == 190
# paid, amount = 2000, 1600
# result == 0

# %% [markdown]
# ### From the amount of change that is left after returning the E2 coins, compute how many E1 coins you should return.
#
# Hint: you can use several lines of programming code. Compute the amount that is left after returning the E2 coins and store it in a variable `left`. Then using the value in `left` compute the number of E1 coins you can return.

# %%
amount = 1610
paid = 2000

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# paid, amount = 2000, 1610
# result == 1
# paid, amount = 2000, 1600
# result == 0

# %% [markdown]
# ### Now a big program. Compute an optimal solution that returns the minimum number of coins as change.
#
# Important: store the respective coins to be returned as change in the variables E2, E1, C50, C20, C10 and C5. The variable names are case sensitive (e.g. use E2 and not e2).
#
# Hint: Use several lines of programming code to store the results. Work from the most expensive coin towards the least expensive. After you determine how many of a certain coin is returned, recompute the amount of change that must still be returned.

# %%
amount = 1610
paid = 2000

# %%
# %%assignment
# left = (paid - amount)
# E2 = ...
# # recompute how much is left
# E1 = ...
# # etc.
# # YOUR CODE HERE

# %%
# %%check
# paid, amount = 2000, 1610
# E2 == 1
# E1 == 1
# C50 == 1
# C20 == 2
# C10 == 0
# C5 == 0
# paid, amount = 2000, 1565
# E2 == 2
# E1 == 0
# C50 == 0
# C20 == 1
# C10 == 1
# C5 == 1
