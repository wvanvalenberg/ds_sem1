# %% [markdown]
# # Else
#
# We can extend an if-statement with an Else-clause:
#
# ```
# if condition:
#     code block
#     with conditional statements
# else:
#     code block
#     with statements that are executed if the
#     condition is not met
# this is after the if-else
# so these lines will be executed regardless of the condition
# but after the if or else code block
# ```
#
# Semantically this is almost the same as:
# ```
# if condition:
#     code block
#     with conditional statements
# if not condition:
#     code block
#     with statements that are executed if the
#     condition is not met
# this is after the if-else
# so these lines will be executed regardless of the condition
# but after the if or else code block
# ```
#
# Except when in the second example, the if conditional statements affect the outcome of the condition.

# %% [markdown]
# # Examples

# %% [markdown]
# Try the example here, with different values for `a`

# %%
a = 10
b = 20
if a > 10:
    a = a + 10
    b = b - 5
else:
    a = a - 1
    b = b + 1
f'a={a} b={b}'

# %% [markdown]
# # Assignments

# %% [markdown]
# #### Write code to increase the speed by 5 if the number of `road_users` < 5

# %%
speed = 50
road_users = 3

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# speed, road_users = 50, 4
# speed == 55
# speed, road_users = 40, 5
# speed == 40

# %% [markdown]
# #### Increase the speed by 5 if the number of `road_users` < 5 or otherwise decrease the speed by 1

# %%
speed = 50
road_users = 3

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# speed, road_users = 50, 4
# speed == 55
# speed, road_users = 40, 5
# speed == 39

# %% [markdown]
# #### The variable `price` says how may one drink costs. The normal price is \$3. However, John should receive a special discount. If he buys more than 4 `drinks`, they are \$2 each. Otherwise he pays the normal fee. Compute the `bill` (which must be the name of the variable) on the order by multiplying `price` with the number of drinks `drink`.

# %%
name = 'John'
drinks = 5

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# name, drinks='John', 5
# bill == 10
# name, drinks='John', 4
# bill == 12
# name, drinks='Jack', 5
# bill == 15
