# %% [markdown]
# # Comprehensions with nested loops
#
# We can also use nested loops within a Comprehension. The first loop is the outer loop and the second loop is the inner loop. We can combine nexted loops with nested conditions.

# %% [markdown]
# # Examples

# %%
a = [1, 2]

# %%
for x in a:
    for y in a:
        print(f'x={x} y={y} x+y={x+y}')

# %%
[ x + y for x in a for y in a ]

# %% [markdown]
# # Assignments

# %% [markdown]
# #### Give all sum of every combination of two `coins` that is not dividable by 20. To determine whether a number is dividable by 20 you can use the modulo operator `%`.

# %%
coins = [50, 20, 10, 5]

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# coins = [200, 100, 50, 20, 10, 5]
# set(result) == {10, 15, 25, 30, 55, 70, 105, 110, 150, 205, 210, 250}
# coins = [50, 20, 10, 5]
# set(result) == {10, 15, 25, 30, 55, 70}

# %% [markdown]
# #### Give all sum of all combinations of three `coins` that are dividable by 65.

# %%
coins = [200, 100, 50, 20, 10, 5]

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# coins = [200, 100, 50, 20, 10, 5]
# set(result) == {65, 130, 260}
# coins = [50, 20, 10, 5]
# set(result) == {65}

# %% [markdown]
# #### How many different permutations are there possible to create the sum of 65 using exactly three `coins`.
#
# Note that 50+10+5 is a different permutation than 10+50+5.

# %%
coins = [200, 100, 50, 20, 10, 5]

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# coins = [200, 100, 50, 20, 10, 5]
# result == 6
# coins = [50, 30, 10, 5]
# result == 9

# %% [markdown]
# #### How many solutions are possible for
#
# $x^2 - 12\cdot x - 10 \cdot y +36 = 0$
#
# with $x, y \in D$
#
# Note, you do not have to give the solutions, only count them. Since it is sufficient to count them, you can use `1` as an expression in the Comprehension.

# %%
D = range(20)

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# D = range(11)
# result == 1
# D = range(20)
# result == 2
