# %% [markdown]
# # Functions
#
# The tools we can use in our programs are not limited to variables and operator. Python also contains a great number of functions that each perform a well defined operation. These functions have a `name` we can use to call them, and we can pass `arguments` in between braces.
#
# The first two functions we will look at are `min` and `max`. The `min` function takes any number of comparable values as arguments and simply returns the lowest of these values. The `max` function returns the highest value.
#
# It is also possible to provide a list of values (e.g. `[3, 2, 5]`) to min or max, then it will return the highest or lowest value from that list.

# %% [markdown]
# # Examples

# %%
min(3, 2, 6)

# %%
a = 6
b = 1
min(a, b)

# %%
min(3, 1, 5, 6)

# %%
max(3, 1, 5, 6)

# %%
ages = [23, 68, 30]

# %%
max(ages)

# %%
min(ages)

# %% [markdown]
# # Assignment

# %% [markdown]
# #### Give the smallest value of x and y

# %%
x = 20
y = 10

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# x, y = 20, 10
# result == 10
# x, y = 30, 20
# result == 20

# %% [markdown]
# #### Give the smallest value of x, y and z

# %%
x = 20
y = 10
z = 5

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# forbidden 5
# x, y, z = 20, 10, 5
# result == 5
# x, y, z = 20, 10, 25
# result == 10
# x, y, z = 2, 10, 25
# result == 2

# %% [markdown]
# #### Give the highest value in weights

# %%
weights = [3, 2, 29]

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# forbidden 29
# weights = [3, 2, 29]
# result == 29
# weights = [3, 2, 1]
# result == 3

# %% [markdown]
# #### Give the length of the shortest person, whose sizes are in `length`

# %%
length = [1.80, 1.65, 2.02, 1.85]

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# forbidden 1.65
# length = [1.80, 1.65, 2.02, 1.85]
# result == 1.65
# length = [1.80, 2.02, 1.85]
# result == 1.80

# %% [markdown]
# #### Give the difference between the tallest and the shortest person, whose sizes are in `length`

# %%
length = [1.80, 1.75, 2.00, 1.85]

# %%
# %%assignment
# # YOUR CODE HERE

# %%
# %%check
# forbidden 0.25
# length = [1.80, 1.75, 2.00, 1.85]
# result == 0.25
# length = [1.50, 2.00]
# result == 0.50
